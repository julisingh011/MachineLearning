# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 

df=pd.read_csv("cuisine_ingredients_with_unnamed.csv")
df["cuisine"].value_counts()
# Out:
# cuisine
# french      1037
# italian     1015
# indian      1010
# thai         991
# japanese     982
# mexican      965
# Name: count, dtype: int64

# %%
thai_df=df[(df["cuisine"]=="thai")]
indian_df=df[(df["cuisine"]=="indian")]
korean_df=df[(df["cuisine"]=="korean")]
japnese_df=df[(df["cuisine"]=="japnese")]
chinese_df=df[(df["cuisine"]=="chinese")]
thai_df
# Out:
#       Unnamed: 0 cuisine  almond  angelica  anise  anise_seed  apple  \
# 3              4    thai       1         0      1           0      0
# 4              5    thai       1         0      1           0      1
# 16            17    thai       0         1      1           1      1
# 24            25    thai       1         1      0           0      0
# 28            29    thai       0         1      0           1      1
# ...          ...     ...     ...       ...    ...         ...    ...
# 5987        5988    thai       1         0      0           1      0
# 5989        5990    thai       1         1      1           1      1
# 5991        5992    thai       1         0      0           1      0
# 5996        5997    thai       0         0      0           1      0
# 5997        5998    thai       1         1      1           0      0
#
#       apple_brandy  apricot  armagnac  whiskey  white_b
# 3                0        1         1        1        1
# ...

# %%
def create_ing_df(df):
    ing_df=df.T.drop(["cuisine","Unnamed: 0"]).sum(axis=1).to_frame('value')
    # ing_df=ing_df[(ing_df.T!=0).any()]
    # ing_df=ing_df.sort_values(by='Value',ascending=False)
    print(ing_df)
create_ing_df(thai_df)
# Out:
#              value
# almond         515
# angelica       492
# anise          520
# anise_seed     507
# apple          484
# apple_brandy   497
# apricot        504
# armagnac       494
# whiskey        461
# white_b        521

# %%
def create_ing_df(df):
    ing_df=df.T.drop(["cuisine","Unnamed: 0"]).sum(axis=1).to_frame('value')
    ing_df=ing_df[(ing_df.T!=0).any()]
    ing_df=ing_df.sort_values(by='value',ascending=False)
    print(ing_df)
create_ing_df(thai_df)
# Out:
#              value
# white_b        521
# anise          520
# almond         515
# anise_seed     507
# apricot        504
# apple_brandy   497
# armagnac       494
# angelica       492
# apple          484
# whiskey        461

# %%
def create_ing_df(df):
    ing_df=df.T.drop(["cuisine","Unnamed: 0"]).sum(axis=1).to_frame('value')
    ing_df=ing_df[(ing_df.T!=0).any()]
    ing_df=ing_df.sort_values(by='value',ascending=False)
    print(ing_df)
create_ing_df(thai_df)
thai_ing=create_ing_df(thai_df)
indian_ing=create_ing_df(indian_df)
korean_ing=create_ing_df(korean_df)
japnese_ing=create_ing_df(japnese_df)
chinese_ing=create_ing_df(chinese_df)
# Out:
#              value
# white_b        521
# anise          520
# almond         515
# anise_seed     507
# apricot        504
# apple_brandy   497
# armagnac       494
# angelica       492
# apple          484
# whiskey        461
#              value
# white_b        521
# anise          520
# almond         515
# anise_seed     507
# apricot        504
# apple_brandy   497
# armagnac       494
# angelica       492
# apple          484
# whiskey        461
#              value
# armagnac       518
# apple          517
# whiskey        513
# apricot        510
# almond         508
# white_b        508
# anise_seed     507
# angelica       502
# anise          498
# apple_brandy   484
# Empty DataFrame
# Columns: [value]
# Index: []
# Empty DataFrame
# Columns: [value]
# Index: []
# Empty DataFrame
# Columns: [value]
# Index: []

# %%
def create_ing_df(df):
    ing_df=df.T.drop(["cuisine","Unnamed: 0"]).sum(axis=1).to_frame('value')
    ing_df=ing_df[(ing_df.T!=0).any()]
    ing_df=ing_df.sort_values(by='value',ascending=False)
    print(ing_df)
    return ing_df
create_ing_df(thai_df)
thai_ing=create_ing_df(thai_df)
indian_ing=create_ing_df(indian_df)
korean_ing=create_ing_df(korean_df)
japnese_ing=create_ing_df(japnese_df)
chinese_ing=create_ing_df(chinese_df)

thai_ing.head(8).plot.barh()
indian_ing.head(8).plot.barh()
korean_ing.head(8).plot.barh()
japnese_ing.head(8).plot.barh()
chinese_ing.head(8).plot.barh()
# Out:
#              value
# white_b        521
# anise          520
# almond         515
# anise_seed     507
# apricot        504
# apple_brandy   497
# armagnac       494
# angelica       492
# apple          484
# whiskey        461
#              value
# white_b        521
# anise          520
# almond         515
# anise_seed     507
# apricot        504
# apple_brandy   497
# armagnac       494
# angelica       492
# apple          484
# whiskey        461
#              value
# armagnac       518
# apple          517
# whiskey        513
# apricot        510
# almond         508
# white_b        508
# anise_seed     507
# angelica       502
# anise          498
# apple_brandy   484
# Empty DataFrame
# Columns: [value]
# Index: []
# Empty DataFrame
# Columns: [value]
# Index: []
# Empty DataFrame
# Columns: [value]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ...

# %%
import seaborn as sns 

ingredients = ["rice", "garlic", "ginger"]

# ensure these columns exist
for col in ingredients:
    if col not in df.columns:
        df[col] = 0   # add empty column

plt.figure(figsize=(10,8))
sns.heatmap(df[ingredients].corr(), annot=True)
plt.show()
# Out:
# C:\Python313\Lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Python313\Lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %%
Features=df.drop(["cuisine","Unnamed: 0","rice","ginger","garlic"],axis=1)
label=df["cuisine"]
label.value_counts()
# Out:
# cuisine
# french      1037
# italian     1015
# indian      1010
# thai         991
# japanese     982
# mexican      965
# Name: count, dtype: int64

# %%
df
# Out:
#       Unnamed: 0  cuisine  almond  angelica  anise  anise_seed  apple  \
# 0              1   indian       0         0      1           0      1
# 1              2   indian       1         1      0           1      1
# 2              3  mexican       1         1      1           1      1
# 3              4     thai       1         0      1           0      0
# 4              5     thai       1         0      1           0      1
# ...          ...      ...     ...       ...    ...         ...    ...
# 5995        5996   indian       1         0      0           1      1
# 5996        5997     thai       0         0      0           1      0
# 5997        5998     thai       1         1      1           0      0
# 5998        5999  mexican       0         0      0           1      0
# 5999        6000  italian       1         0      1           0      0
#
#       apple_brandy  apricot  armagnac  whiskey  white_b  rice  garlic  ginger
# ...

# %%
pip install imblearn
# Out:
# ...
#
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
#    ---------------------------------------- 0/2 [imbalanced-learn]
# ...

# %%
from imblearn.over_sampling import SMOTE

sam=SMOTE()
x,y=sam.fit_resample(Features,label)
y.value_counts()
# Out:
# cuisine
# indian      1037
# mexican     1037
# thai        1037
# french      1037
# italian     1037
# japanese    1037
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression,SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,confusion_matrix,classification_report

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
lr=LogisticRegression(multi_class='ovr',solver='liblinear')
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# C:\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1281: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1296: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(
# array([[32, 29, 45, 44, 27, 37],
#        [26, 23, 58, 41, 28, 42],
#        [31, 19, 45, 36, 21, 39],
#        [20, 26, 48, 30, 37, 44],
#        [31, 35, 42, 43, 26, 38],
#        [26, 29, 46, 38, 25, 38]])

# %%
cp=classification_report(y_test,y_pred)
print(cp)
# Out:
#               precision    recall  f1-score   support
#
#       french       0.19      0.15      0.17       214
#       indian       0.14      0.11      0.12       218
#      italian       0.16      0.24      0.19       191
#     japanese       0.13      0.15      0.14       205
#      mexican       0.16      0.12      0.14       215
#         thai       0.16      0.19      0.17       202
#
#     accuracy                           0.16      1245
#    macro avg       0.16      0.16      0.15      1245
# weighted avg       0.16      0.16      0.15      1245
