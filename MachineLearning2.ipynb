# %%
import numpy as np
import pandas as pd 

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error, r2_score

# %%
import matplotlib.pyplot as plt 
np.random.seed(0)
x=np.random.rand(100,1)
x
# Out:
# array([[0.5488135 ],
#        [0.71518937],
#        [0.60276338],
#        [0.54488318],
#        [0.4236548 ],
#        [0.64589411],
#        [0.43758721],
#        [0.891773  ],
#        [0.96366276],
#        [0.38344152],
#        [0.79172504],
#        [0.52889492],
#        [0.56804456],
#        [0.92559664],
#        [0.07103606],
#        [0.0871293 ],
#        [0.0202184 ],
#        [0.83261985],
#        [0.77815675],
#        [0.87001215],
#        [0.97861834],
#        [0.79915856],
#        [0.46147936],
#        [0.78052918],
#        [0.11827443],
#        [0.63992102],
#        [0.14335329],
#        [0.94466892],
#        [0.52184832],
#        [0.41466194],
#        [0.26455561],
#        [0.77423369],
#        [0.45615033],
#        [0.56843395],
#        [0.0187898 ],
#        [0.6176355 ],
#        [0.61209572],
#        [0.616934  ],
#        [0.94374808],
#        [0.6818203 ],
#        [0.3595079 ],
#        [0.43703195],
#        [0.6976312 ],
#        [0.06022547],
#        [0.66676672],
#        [0.67063787],
#        [0.21038256],
#        [0.1289263 ],
#        [0.31542835],
#        [0.36371077],
#        [0.57019677],
#        [0.43860151],
#        [0.98837384],
#        [0.10204481],
#        [0.20887676],
#        [0.16130952],
#        [0.65310833],
#        [0.2532916 ],
#        [0.46631077],
#        [0.24442559],
#        [0.15896958],
#        [0.11037514],
#        [0.65632959],
#        [0.13818295],
#        [0.19658236],
#        [0.36872517],
#        [0.82099323],
#        [0.09710128],
#        [0.83794491],
#        [0.09609841],
#        [0.97645947],
#        [0.4686512 ],
#        [0.97676109],
#        [0.60484552],
#        [0.73926358],
#        [0.03918779],
#        [0.28280696],
#        [0.12019656],
#        [0.2961402 ],
#        [0.11872772],
#        [0.31798318],
#        [0.41426299],
#        [0.0641475 ],
#        [0.69247212],
#        [0.56660145],
#        [0.26538949],
#        [0.52324805],
#        [0.09394051],
#        [0.5759465 ],
#        [0.9292962 ],
#        [0.31856895],
#        [0.66741038],
#        [0.13179786],
#        [0.7163272 ],
#        [0.28940609],
#        [0.18319136],
#        [0.58651293],
#        [0.02010755],
#        [0.82894003],
#        [0.00469548]])

# %%
y =20 * x+1+np.random.randn(100,1)
y
# Out:
# array([[10.81112024],
#        [16.20461381],
#        [13.52092996],
#        [10.36141997],
#        [10.96134818],
#        [15.81377144],
#        [10.9305238 ],
#        [18.65553518],
#        [19.20250259],
#        [ 9.7232821 ],
#        [16.43132381],
#        [12.80034347],
#        [12.5691662 ],
#        [20.4885718 ],
#        [ 2.77708756],
#        [ 3.44915916],
#        [ 1.41486797],
#        [19.4382674 ],
#        [16.69004711],
#        [18.80223233],
#        [22.45551754],
#        [15.63541222],
#        [ 8.95910225],
#        [17.57998023],
#        [ 2.19236511],
#        [15.74204161],
#        [ 3.45344677],
#        [19.14592353],
#        [13.35990846],
#        [10.77375359],
#        [ 8.1586712 ],
#        [17.39071845],
#        [ 9.26178096],
#        [14.27874393],
#        [ 1.10779264],
#        [14.15516634],
#        [14.18916642],
#        [13.18366984],
#        [20.48904094],
#        [15.55861265],
#        [ 8.56658354],
#        [ 8.64123829],
#        [15.25086209],
#        [ 3.53089533],
#        [13.64076645],
#        [14.26312285],
#        [ 4.77249767],
#        [ 5.42778968],
#        [ 7.98086178],
#        [ 8.68167726],
#        [11.63401933],
#        [10.31127946],
#        [20.0931441 ],
#        [ 3.07272677],
#        [ 4.54168904],
#        [ 4.90262365],
#        [14.63875733],
#        [ 5.8575333 ],
#        [10.72222217],
#        [ 4.79545033],
#        [ 2.68813408],
#        [ 3.64689452],
#        [14.29326528],
#        [ 4.39869046],
#        [ 7.31479201],
#        [ 9.3189829 ],
#        [16.50704237],
#        [ 4.0590418 ],
#        [16.44299074],
#        [ 2.46038355],
#        [20.46094769],
#        [12.08636675],
#        [19.79046694],
#        [12.27047186],
#        [15.68681906],
#        [ 1.12027756],
#        [ 7.78277517],
#        [ 2.32399972],
#        [ 5.7753353 ],
#        [ 2.93673433],
#        [ 6.86163114],
#        [11.21479194],
#        [ 3.23237073],
#        [14.93699363],
#        [11.10659357],
#        [ 7.1521528 ],
#        [10.46474572],
#        [ 1.33403912],
#        [13.7069597 ],
#        [19.90286656],
#        [ 8.29223787],
#        [14.66693525],
#        [ 4.49278786],
#        [14.67551849],
#        [ 5.75387902],
#        [ 5.34542176],
#        [11.92684903],
#        [ 0.71260115],
#        [17.12326808],
#        [ 1.11138868]])

# %%
df =pd.DataFrame({"x":x.flatten(),"y":y.flatten()})
df
# Out:
#            x          y
# 0   0.548814  10.811120
# 1   0.715189  16.204614
# 2   0.602763  13.520930
# 3   0.544883  10.361420
# 4   0.423655  10.961348
# ..       ...        ...
# 95  0.183191   5.345422
# 96  0.586513  11.926849
# 97  0.020108   0.712601
# 98  0.828940  17.123268
# 99  0.004695   1.111389
#
# [100 rows x 2 columns]

# %%
plt.scatter(x,y)
plt.xlabel("Feature")
plt.ylabel("Target")
plt.show()

# %%
from  sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42) 
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
mse=mean_squared_error(y_test,y_pred)
r2scr=r2_score(y_test,y_pred)
print(f"Mean Squared error :{mse:2f}")
print(f"r2 score{r2scr:2f}")
# Out:
# Mean Squared error :0.917753
# r2 score0.957688

# %%
plt.scatter(x_test,y_test,label="Data")
plt.plot(x_test,y_pred,color="red",linewidth=2,label="Regression line")

plt.ylabel("Target")
plt.legend()
plt.show()
