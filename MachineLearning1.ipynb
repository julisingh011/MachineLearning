# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.7 MB 1.4 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/8.7 MB 1.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/8.7 MB 1.6 MB/s eta 0:00:05
#    -------- ------------------------------- 1.8/8.7 MB 1.7 MB/s eta 0:00:05
#    --------- ------------------------------ 2.1/8.7 MB 1.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.4/8.7 MB 1.8 MB/s eta 0:00:04
#    ------------- -------------------------- 2.9/8.7 MB 1.7 MB/s eta 0:00:04
#    --------------- ------------------------ 3.4/8.7 MB 1.8 MB/s eta 0:00:03
#    ------------------ --------------------- 3.9/8.7 MB 1.8 MB/s eta 0:00:03
#    ------------------ --------------------- 3.9/8.7 MB 1.8 MB/s eta 0:00:03
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
import pandas as pd 
import matplotlib.pyplot as plt

df=pd.read_csv("areaprice.csv")
df
# Out:
#    area    price
# 0  1000  4500000
# 1  1200  5000000
# 2  1500  5500000
# 3  2000  6500000
# 4  2300  7000000
# 5  2500  7550000
# 6  3000  8500000
# 7  3500  9500000

# %%
plt.plot(df.area,df.price,marker='+')
plt.show()

# %%
dfa = df.drop('price',axis=1)
dfa
# Out:
#    area
# 0  1000
# 1  1200
# 2  1500
# 3  2000
# 4  2300
# 5  2500
# 6  3000
# 7  3500

# %%
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

lreg = LinearRegression()

# %%
lreg=LinearRegression()
lreg.fit(dfa.values,df['price'].values)
# Out:
# LinearRegression()

# %%
lreg=LinearRegression()
lreg.fit(dfa.values,df['price'].values)
# Out:
# LinearRegression()

# %%
lreg.predict([[2200]])
# Out:
# array([6904971.98879552])

# %%
lreg.predict([[2200]])
# Out:
# array([6904971.98879552])

# %%
m=lreg.coef_
c=lreg.intercept_

print(m)
print(c)
# Out:
# [1982.95985061]
# 2542460.3174603162

# %%
yhat=m*2200 + c
print(yhat)
# Out:
# [6904971.98879552]

# %%
df_areas={'areas':[65,78,73,90]}
dfor=pd.DataFrame(df_areas)
dfor
# Out:
#    areas
# 0     65
# 1     78
# 2     73
# 3     90

# %%
pred=lreg.predict(dfor.values)
dfor['Predictions']=pred
dfor
# Out:
#    areas   Predictions
# 0     65  2.671353e+06
# 1     78  2.697131e+06
# 2     73  2.687216e+06
# 3     90  2.720927e+06
